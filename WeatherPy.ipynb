# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 607

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Change the units to metric 
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=" + units

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['lat']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | susuman
# City not found. Skipping...
# Processing Record 2 of Set 1 | karystos
# City not found. Skipping...
# Processing Record 3 of Set 1 | papatowai
# City not found. Skipping...
# Processing Record 4 of Set 1 | ancud
# City not found. Skipping...
# Processing Record 5 of Set 1 | san antonio de pale
# City not found. Skipping...
# Processing Record 6 of Set 1 | alofi
# City not found. Skipping...
# Processing Record 7 of Set 1 | hotan
# City not found. Skipping...
# Processing Record 8 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 9 of Set 1 | sungailiat
# City not found. Skipping...
# Processing Record 10 of Set 1 | poronaysk
# City not found. Skipping...
# Processing Record 11 of Set 1 | crane
# City not found. Skipping...
# Processing Record 12 of Set 1 | invercargill
# City not found. Skipping...
# Processing Record 13 of Set 1 | colchani
# City not found. Skipping...
# Processing Record 14 of Set 1 | yuzhno-kurilsk
# City not found. Skipping...
# Processing Record 15 of Set 1 | rabigh
# City not found. Skipping...
# Processing Record 16 of Set 1 | wailua homesteads
# City not found. Skipping...
# Processing Record 17 of Set 1 | weno
# City not found. Skipping...
# Processing Record 18 of Set 1 | iten
# City not found. Skipping...
# Processing Record 19 of Set 1 | taksimo
# City not found. Skipping...
# Processing Record 20 of Set 1 | namibe
# City not found. Skipping...
# Processing Record 21 of Set 1 | nabire
# City not found. Skipping...
# Processing Record 22 of Set 1 | phan rang-thap cham
# City not found. Skipping...
# Processing Record 23 of Set 1 | inarajan village
# City not found. Skipping...
# Processing Record 24 of Set 1 | albany
# City not found. Skipping...
# Processing Record 25 of Set 1 | chipinge
# City not found. Skipping...
# Processing Record 26 of Set 1 | adamstown
# City not found. Skipping...
# Processing Record 27 of Set 1 | port mathurin
# City not found. Skipping...
# Processing Record 28 of Set 1 | alice springs
# City not found. Skipping...
# Processing Record 29 of Set 1 | formosa
# City not found. Skipping...
# Processing Record 30 of Set 1 | talnakh
# City not found. Skipping...
# Processing Record 31 of Set 1 | sabzevar
# City not found. Skipping...
# Processing Record 32 of Set 1 | nemuro
# City not found. Skipping...
# Processing Record 33 of Set 1 | georgetown
# City not found. Skipping...
# Processing Record 34 of Set 1 | bandar-e anzali
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 12 | vershino-darasunskiy
# City not found. Skipping...
# Processing Record 44 of Set 12 | westport
# City not found. Skipping...
# Processing Record 45 of Set 12 | dikirnis
# City not found. Skipping...
# Processing Record 46 of Set 12 | villa gesell
# City not found. Skipping...
# Processing Record 47 of Set 12 | borzya
# City not found. Skipping...
# Processing Record 48 of Set 12 | aripuana
# City not found. Skipping...
# Processing Record 49 of Set 12 | xingcheng
# City not found. Skipping...
# Processing Record 0 of Set 13 | ibipeba
# City not found. Skipping...
# Processing Record 1 of Set 13 | greymouth
# City not found. Skipping...
# Processing Record 2 of Set 13 | kutum
# City not found. Skipping...
# Processing Record 3 of Set 13 | anqing
# City not found. Skipping...
# Processing Record 4 of Set 13 | dakhla
# City not found. Skipping...
# Processing Record 5 of Set 13 | dawson creek
# City not found. Skipping...
# Processing Record 6 of Set 13 | tuxtepec
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# Series([], dtype: int64)

# %%
# Display sample data
city_data_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title("Latitude vs Temperature")


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[124], line 2
#       1 # Build scatter plot for latitude vs. temperature
# ----> 2 plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"])
#       4 # Incorporate the other graph properties
#       5 plt.xlabel("Latitude")
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Lat'

# %%
print(city_data_df.head())
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitude vs Humidity")


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 2
#       1 # Build the scatter plots for latitude vs. humidity
# ----> 2 plt.scatter(city_data_df["Lat"], city_data_df["Humidity"])
#       4 # Incorporate the other graph properties
#       5 plt.xlabel("Latitude")
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'Lat'

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitude vs Cloudiness")


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[108], line 2
#       1 # Build the scatter plots for latitude vs. cloudiness
# ----> 2 plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"])
#       4 # Incorporate the other graph properties
#       5 plt.xlabel("Latitude")
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'Lat'

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Latitude vs Wind Speed")


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[109], line 2
#       1 # Build the scatter plots for latitude vs. wind speed
# ----> 2 plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"])
#       4 # Incorporate the other graph properties
#       5 plt.xlabel("Latitude")
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'Lat'

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept,rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
print(regress_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[110], line 2
#       1 # Define a function to create Linear Regression plots
# ----> 2 (slope, intercept,rvalue, pvalue, stderr) = linregress(x_values, y_values)
#       4 regress_values = x_values * slope + intercept
#       5 print(regress_values)
#
# NameError: name 'x_values' is not defined

# %%
# Line Equation 
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[112], line 2
#       1 # Line Equation
# ----> 2 line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#       3 print(line_eq)
#
# NameError: name 'slope' is not defined

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['lat']>= 0]

# Display sample data
northern_hemi_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[111], line 2
#       1 # Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# ----> 2 northern_hemi_df = city_data_df[city_data_df['lat']>= 0]
#       4 # Display sample data
#       5 northern_hemi_df.head()
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'lat'

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 2
#       1 # Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# ----> 2 southern_hemi_df = city_data_df[city_data_df['lat'] < 0]
#       4 # Display sample data
#       5 southern_hemi_df.head()
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'lat'

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
northern_x_value = northern_hemi_df["Lat"]
northern_temp = northern_hemi_df ["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress (northern_x_value, northern_temp)
regress_values = northern_x_value * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(northern_x_value, northern_temp)
plt.plot (northern_x_value, regress_values, color = "firebrick")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.annotate(line_eq, (5, -5.5), fontsize=15, color="k")
plt.title("latitude vs Temperature")

print(f" The r^2-value is: {rvalue**2}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[113], line 2
#       1 # Linear regression on Northern Hemisphere
# ----> 2 northern_x_value = northern_hemi_df["Lat"]
#       3 northern_temp = northern_hemi_df ["Max Temp"]
#       5 (slope, intercept, rvalue, pvalue, stderr) = linregress (northern_x_value, northern_temp)
#
# NameError: name 'northern_hemi_df' is not defined

# %%
# Linear regression on Southern Hemisphere
southern_x_value = southern_hemi_df["Lat"]
southern_temp = southern_hemi_df ["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress (southern_x_value, southern_temp)
regress_values = southern_x_value * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(southern_x_value, southern_temp)
plt.plot (southern_x_value, regress_values, color = "firebrick")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.annotate(line_eq, (-25, 5), fontsize=15, color="k")
plt.title("latitude vs Temperature")

print(f" The r^2-value is: {rvalue**2}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[114], line 2
#       1 # Linear regression on Southern Hemisphere
# ----> 2 southern_x_value = southern_hemi_df["Lat"]
#       3 southern_temp = southern_hemi_df ["Max Temp"]
#       5 (slope, intercept, rvalue, pvalue, stderr) = linregress (southern_x_value, southern_temp)
#
# NameError: name 'southern_hemi_df' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_x_value = northern_hemi_df["Lat"]
northern_humidity = northern_hemi_df ["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress (northern_x_value, northern_humidity)
regress_values = northern_x_value * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(northern_x_value, northern_humidity)
plt.plot (northern_x_value, regress_values, color = "firebrick")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq, (40, 10), fontsize=15, color="k")
plt.title("latitude vs Humidity")

print(f" The r^2-value is: {rvalue**2}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 2
#       1 # Northern Hemisphere
# ----> 2 northern_x_value = northern_hemi_df["Lat"]
#       3 northern_humidity = northern_hemi_df ["Humidity"]
#       5 (slope, intercept, rvalue, pvalue, stderr) = linregress (northern_x_value, northern_humidity)
#
# NameError: name 'northern_hemi_df' is not defined

# %%
# Southern Hemisphere
southern_x_value = southern_hemi_df["Lat"]
southern_humidity = southern_hemi_df ["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress (southern_x_value, southern_humidity)
regress_values = southern_x_value * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(southern_x_value, southern_humidity)
plt.plot (southern_x_value, regress_values, color = "firebrick")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq, (-55, 10), fontsize=15, color="k")
plt.title("latitude vs Humidity")

print(f" The r^2-value is: {rvalue**2}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 2
#       1 # Southern Hemisphere
# ----> 2 southern_x_value = southern_hemi_df["Lat"]
#       3 southern_humidity = southern_hemi_df ["Humidity"]
#       5 (slope, intercept, rvalue, pvalue, stderr) = linregress (southern_x_value, southern_humidity)
#
# NameError: name 'southern_hemi_df' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_x_value = northern_hemi_df["Lat"]
northern_cloudiness = northern_hemi_df ["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress (northern_x_value, northern_cloudiness)
regress_values = northern_x_value * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(northern_x_value, northern_cloudiness)
plt.plot (northern_x_value, regress_values, color = "firebrick")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq, (45, 25), fontsize=15, color="k")
plt.title("latitude vs Cloudiness")

print(f" The r^2-value is: {rvalue**2}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 2
#       1 # Northern Hemisphere
# ----> 2 northern_x_value = northern_hemi_df["Lat"]
#       3 northern_cloudiness = northern_hemi_df ["Cloudiness"]
#       5 (slope, intercept, rvalue, pvalue, stderr) = linregress (northern_x_value, northern_cloudiness)
#
# NameError: name 'northern_hemi_df' is not defined

# %%
# Southern Hemisphere
southern_x_value = southern_hemi_df["Lat"]
southern_cloudiness = southern_hemi_df ["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress (southern_x_value, southern_cloudiness)
regress_values = southern_x_value * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(southern_x_value, southern_cloudiness)
plt.plot (southern_x_value, regress_values, color = "firebrick")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq, (-55, 83), fontsize=15, color="k")
plt.title("latitude vs Cloudiness")

print(f" The r^2-value is: {rvalue**2}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 2
#       1 # Southern Hemisphere
# ----> 2 southern_x_value = southern_hemi_df["Lat"]
#       3 southern_cloudiness = southern_hemi_df ["Cloudiness"]
#       5 (slope, intercept, rvalue, pvalue, stderr) = linregress (southern_x_value, southern_cloudiness)
#
# NameError: name 'southern_hemi_df' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_x_value = northern_hemi_df["Lat"]
northern_wind_speed = northern_hemi_df ["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress (northern_x_value, northern_wind_speed)
regress_values = northern_x_value * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(northern_x_value, northern_wind_speed)
plt.plot (northern_x_value, regress_values, color = "firebrick")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq, (0, 14), fontsize=15, color="k")
plt.title("latitude vs Wind Speed")

print(f" The r^2-value is: {rvalue**2}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 2
#       1 # Northern Hemisphere
# ----> 2 northern_x_value = northern_hemi_df["Lat"]
#       3 northern_wind_speed = northern_hemi_df ["Wind Speed"]
#       5 (slope, intercept, rvalue, pvalue, stderr) = linregress (northern_x_value, northern_wind_speed)
#
# NameError: name 'northern_hemi_df' is not defined

# %%
# Southern Hemisphere
southern_x_value = southern_hemi_df["Lat"]
southern_wind_speed = southern_hemi_df ["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress (southern_x_value, southern_wind_speed)
regress_values = southern_x_value * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(southern_x_value, southern_wind_speed)
plt.plot (southern_x_value, regress_values, color = "firebrick")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq, (-30, 15), fontsize=15, color="k")
plt.title("latitude vs Wind Speed")

print(f" The r^2-value is: {rvalue**2}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 # Southern Hemisphere
# ----> 2 southern_x_value = southern_hemi_df["Lat"]
#       3 southern_wind_speed = southern_hemi_df ["Wind Speed"]
#       5 (slope, intercept, rvalue, pvalue, stderr) = linregress (southern_x_value, southern_wind_speed)
#
# NameError: name 'southern_hemi_df' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
